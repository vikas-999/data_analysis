# %%
#reading the csv file in pandas
import pandas as pd
df = pd.read_csv('ZillowApartmens_msp.csv')
df
# Out:
#      Unnamed: 0                          apt_names  \
# 0             0                Platform Apartments
# 1             1                              Ratio
# 2             2                    Moda on Raymond
# 3             3  The Collection at Highland Bridge
# 4             4                          The Reeve
# ..          ...                                ...
# 478         478                  Townhome for Rent
# 479         479                     House for Rent
# 480         480                  Townhome for Rent
# 481         481                     House for Rent
# 482         482                     House for Rent
#
#                                         apt_address       apt_price  \
# 0             747 Hampden Ave, Saint Paul, MN 55114  $1,245 - 2,225
# 1      909 Gould Ave NE, Columbia Heights, MN 55421    $950 - 2,763
# 2             760 Raymond Ave, Saint Paul, MN 55114  $1,094 - 2,875
# 3            800 Cretin Ave S, Saint Paul, MN 55116  $1,355 - 6,645
# ...

# %%
#information about the data frame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 483 entries, 0 to 482
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   483 non-null    int64
#  1   apt_names    483 non-null    object
#  2   apt_address  483 non-null    object
#  3   apt_price    405 non-null    object
#  4   apt_type     405 non-null    object
#  5   apt_link     483 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 22.8+ KB

# %%
#we have price ranges in apt_price column so splitting those columns
df[['apt_price','apt_price2']] = df['apt_price'].str.split('-',1, expand = True)
# Out:
# C:\Users\13203\AppData\Local\Temp\ipykernel_2440\2788401900.py:2: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df[['apt_price','apt_price2']] = df['apt_price'].str.split('-',1, expand = True)

# %%
#after splitting
df
# Out:
#      Unnamed: 0                          apt_names  \
# 0             0                Platform Apartments
# 1             1                              Ratio
# 2             2                    Moda on Raymond
# 3             3  The Collection at Highland Bridge
# 4             4                          The Reeve
# ..          ...                                ...
# 478         478                  Townhome for Rent
# 479         479                     House for Rent
# 480         480                  Townhome for Rent
# 481         481                     House for Rent
# 482         482                     House for Rent
#
#                                         apt_address apt_price  \
# 0             747 Hampden Ave, Saint Paul, MN 55114   $1,245
# 1      909 Gould Ave NE, Columbia Heights, MN 55421     $950
# 2             760 Raymond Ave, Saint Paul, MN 55114   $1,094
# 3            800 Cretin Ave S, Saint Paul, MN 55116   $1,355
# ...

# %%
#cleaning the data
df['apt_price'] = df['apt_price'].str.replace('$', '', regex=True)
df['apt_price'] = df['apt_price'].str.replace(',', '', regex=True)
df['apt_price2'] = df['apt_price2'].str.replace(',', '', regex=True)
df['apt_price'] = df['apt_price'].str.replace(' /mo', '', regex=True)
df['apt_price'] = df['apt_price'].str.replace('nan', '', regex=True)
df['apt_type'] = df['apt_type'].str.replace('NaN', '', regex=True)
df['apt_price'] = df['apt_price'].str.replace('NA', '', regex=True)
df
# Out:
#      Unnamed: 0                          apt_names  \
# 0             0                Platform Apartments
# 1             1                              Ratio
# 2             2                    Moda on Raymond
# 3             3  The Collection at Highland Bridge
# 4             4                          The Reeve
# ..          ...                                ...
# 478         478                  Townhome for Rent
# 479         479                     House for Rent
# 480         480                  Townhome for Rent
# 481         481                     House for Rent
# 482         482                     House for Rent
#
#                                         apt_address apt_price  \
# 0             747 Hampden Ave, Saint Paul, MN 55114     1245
# 1      909 Gould Ave NE, Columbia Heights, MN 55421      950
# 2             760 Raymond Ave, Saint Paul, MN 55114     1094
# 3            800 Cretin Ave S, Saint Paul, MN 55116     1355
# ...

# %%
#replacing the values so that to perfome operations on that column
df1 = df.replace({'apt_price': {'Call for Rent': ''}}, regex=True)
df1
# Out:
#      Unnamed: 0                          apt_names  \
# 0             0                Platform Apartments
# 1             1                              Ratio
# 2             2                    Moda on Raymond
# 3             3  The Collection at Highland Bridge
# 4             4                          The Reeve
# ..          ...                                ...
# 478         478                  Townhome for Rent
# 479         479                     House for Rent
# 480         480                  Townhome for Rent
# 481         481                     House for Rent
# 482         482                     House for Rent
#
#                                         apt_address apt_price  \
# 0             747 Hampden Ave, Saint Paul, MN 55114     1245
# 1      909 Gould Ave NE, Columbia Heights, MN 55421      950
# 2             760 Raymond Ave, Saint Paul, MN 55114     1094
# 3            800 Cretin Ave S, Saint Paul, MN 55116     1355
# ...

# %%
# convert string to an integer
df1['apt_price'] = pd.to_numeric(df1['apt_price'])
df1['apt_price2'] = pd.to_numeric(df1['apt_price2'])
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 483 entries, 0 to 482
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   483 non-null    int64
#  1   apt_names    483 non-null    object
#  2   apt_address  483 non-null    object
#  3   apt_price    396 non-null    float64
#  4   apt_type     405 non-null    object
#  5   apt_link     483 non-null    object
#  6   apt_price2   360 non-null    float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 26.5+ KB

# %%
# fetching the properties lessesthan 1000$
bel_1000 = df1[df1['apt_price'] < 1000]
bel_1000
# Out:
#      Unnamed: 0                         apt_names  \
# 1             1                             Ratio
# 5             5                Solhaus Apartments
# 14           14                  Artistry on 10th
# 17           17                    Jax Apartments
# 28           28                       Lake Pointe
# ..          ...                               ...
# 391         391  The Pavilion on Berry Apartments
# 392         392        Highcrest Manor Apartments
# 394         394            Uptown West Apartments
# 395         395                   Gateway Commons
# 396         396               Brittany Apartments
#
#                                          apt_address  apt_price  \
# 1       909 Gould Ave NE, Columbia Heights, MN 55421      950.0
# 5            2428 Delaware St, Minneapolis, MN 55414      965.0
# 14               95 S 10th St, Minneapolis, MN 55403      915.0
# 17         2333 Jackson St NE, Minneapolis, MN 55418      950.0
# ...

# %%
# fetching the properties greaterthan 1500$
above_1500 = df1[df1['apt_price'] > 1500]
above_1500
# Out:
#      Unnamed: 0                    apt_names  \
# 7             7            Arcata Apartments
# 11           11             Xenia Apartments
# 18           18                     LAKEHAUS
# 24           24                       Moment
# 29           29                   The Aubrey
# ..          ...                          ...
# 399         399            3639 Stinson Blvd
# 400         400  4745 Minnehaha Ave Unit 103
# 401         401       1240 S 2nd St Unit 932
# 402         402        3624 E 38th St Unit D
# 404         404            6009 Xerxes Ave S
#
#                                        apt_address  apt_price  \
# 7           901 Xenia Ave S, Minneapolis, MN 55416     1590.0
# 11          770 Xenia Ave S, Minneapolis, MN 55416     1620.0
# 18           3100 W Lake St, Minneapolis, MN 55416     1685.0
# 24         650 Portland Ave, Minneapolis, MN 55415     1577.0
# 29   4220-4230 Nicollet Ave, Minneapolis, MN 55409     2699.0
# ...

# %%
#fetching row in between range
df1.loc[df1['apt_price'].between(1500, 2000)]
# Out:
#      Unnamed: 0                                      apt_names  \
# 7             7                              Arcata Apartments
# 11           11                               Xenia Apartments
# 18           18                                       LAKEHAUS
# 24           24                                         Moment
# 30           30                                   The Vicinity
# 31           31                                      1800 Lake
# 34           34                                     The Encore
# 35           35                              Forte on the Park
# 36           36                           Ironclad Residential
# 39           39                                           EXPO
# 41           41                      Solhavn/Soltva/NOLO Flats
# 44           44                                       Borealis
# 45           45                              Gibson Apartments
# 48           48                                    The Archive
# ...

# %%
# apartment names contains minneapolis
df1[df1['apt_names'].str.contains('Minneapolis')]
# Out:
#      Unnamed: 0                     apt_names  \
# 10           10  Minneapolis Grand Apartments
# 106         106  Yugo Minneapolis Sydney Hall
# 215         215    Student | HERE Minneapolis
# 357         357               Hub Minneapolis
#
#                                   apt_address  apt_price         apt_type  \
# 10    2401 Chicago Ave, Minneapolis, MN 55404     1050.0  Studio - 2 Beds
# 106    308 15th Ave SE, Minneapolis, MN 55414      649.0  Studio - 4 Beds
# 215     2813 4th St SE, Minneapolis, MN 55414     1279.0  Studio - 2 Beds
# 357  311 Harvard St SE, Minneapolis, MN 55414      670.0  Studio - 4 Beds
#
#                                               apt_link  apt_price2
# 10   https://www.apartments.com/moda-on-raymond-sai...      1670.0
# 106  https://www.apartments.com/york-place-apartmen...      2118.0
# 215  https://www.apartments.com/tree-tops-minneapol...      2409.0
# 357  https://www.apartments.com/luna-minneapolis-mn...      1935.0

# %%
# apartments in minneapolis(zip:55414)
df1[df1['apt_address'].str.contains('55414')]
# Out:
#      Unnamed: 0                                      apt_names  \
# 5             5                             Solhaus Apartments
# 13           13                                         Rafter
# 33           33                                22 on the River
# 39           39                                           EXPO
# 45           45                              Gibson Apartments
# 50           50                   The Station at Malcolm Yards
# 52           52                                    The Elysian
# 59           59                                         Hencen
# 64           64              Sela Campus University Apartments
# 106         106                   Yugo Minneapolis Sydney Hall
# 137         137                             East River Terrace
# 148         148                              Moerty Apartments
# 152         152    Marko Apartments- Pre-leasing for Fall 2023
# 156         156                                     Coze Flats
# ...

# %%
#checking for apartments in minneapolis(zip:55414) and also with apartment price greater than 1700
df1[(df1['apt_address'].str.contains('55401')) & (df1['apt_price'] > 1700.0)]
# Out:
#      Unnamed: 0          apt_names  \
# 44           44           Borealis
# 56           56               Vesi
# 314         314         The Copham
# 324         324  SECOND AND SECOND
#
#                                      apt_address  apt_price  apt_type  \
# 44           721 N 1st St, Minneapolis, MN 55401     1985.0  1-2 Beds
# 56       730 1/2 N 1st St, Minneapolis, MN 55401     1760.0  1-2 Beds
# 314  607 N Washington Ave, Minneapolis, MN 55401     1793.0  1-2 Beds
# 324          120 2nd St N, Minneapolis, MN 55401     1735.0  1-2 Beds
#
#                                               apt_link  apt_price2
# 44   https://www.apartments.com/xenia-apartments-mi...      3275.0
# 56   https://www.apartments.com/artistry-on-10th-mi...      6065.0
# 314  https://www.apartments.com/the-venue-on-knox-m...      2465.0
# 324  https://www.apartments.com/the-asher-minneapol...      3682.0

# %%
#creating a new dataframe by replacing NaN values to beds in apt_type column
df2=df1.fillna('Beds')

# %%
#reading the new dataframe
df2
# Out:
#      Unnamed: 0                          apt_names  \
# 0             0                Platform Apartments
# 1             1                              Ratio
# 2             2                    Moda on Raymond
# 3             3  The Collection at Highland Bridge
# 4             4                          The Reeve
# ..          ...                                ...
# 478         478                  Townhome for Rent
# 479         479                     House for Rent
# 480         480                  Townhome for Rent
# 481         481                     House for Rent
# 482         482                     House for Rent
#
#                                         apt_address apt_price  \
# 0             747 Hampden Ave, Saint Paul, MN 55114    1245.0
# 1      909 Gould Ave NE, Columbia Heights, MN 55421     950.0
# 2             760 Raymond Ave, Saint Paul, MN 55114    1094.0
# 3            800 Cretin Ave S, Saint Paul, MN 55116    1355.0
# ...

# %%
#checking the apatments with 3 bed rooms
df2[df2['apt_type'].str.contains('3')]
# Out:
#      Unnamed: 0                apt_names  \
# 4             4                The Reeve
# 6             6             365 Nicollet
# 9             9                      LPM
# 12           12            HQ Apartments
# 13           13                   Rafter
# ..          ...                      ...
# 341         341          Lowry Row Homes
# 349         349  The Birchway Apartments
# 376         376                     Aria
# 390         390        Henley Apartments
# 401         401   1240 S 2nd St Unit 932
#
#                                          apt_address apt_price  \
# 4          4600 Lake Road Ave, Robbinsdale, MN 55422    1225.0
# 6           365 Nicollet Mall, Minneapolis, MN 55401    1292.0
# 9              1369 Spruce Pl, Minneapolis, MN 55403    1209.0
# 12         816 Portland Ave S, Minneapolis, MN 55404    1075.0
# 13         333 E Hennepin Ave, Minneapolis, MN 55414    1255.0
# ..                                               ...       ...
# ...
